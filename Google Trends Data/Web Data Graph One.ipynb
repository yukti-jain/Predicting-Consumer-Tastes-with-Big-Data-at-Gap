# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_gap = pd.read_csv("GPS.csv", parse_dates = ['Date']) #Parse dates
df_ae = pd.read_csv("AEO.csv", parse_dates = ['Date'])
df_gap.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0 2014-01-28  37.040001  37.240002  36.570000  36.869999  26.697081  5870800
# 1 2014-01-29  36.669998  37.180000  36.660000  36.790001  26.639156  5329000
# 2 2014-01-30  37.000000  38.209999  36.910000  38.040001  27.544268  9529100
# 3 2014-01-31  37.419998  38.290001  37.380001  38.080002  27.573235  5880400
# 4 2014-02-03  38.020000  38.020000  37.099998  37.250000  26.972242  6719500

# %%
#check dtypes
df_gap.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df_ae.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df_anf.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# calculate percentage change over time
df_gap['price_percentage_change_closing'] = ((df_gap['Close'] - df_gap['Close'][0]) / df_gap['Close'][0]) * 100
df_ae['price_percentage_change_closing'] = ((df_ae['Close'] - df_ae['Close'][0]) / df_ae['Close'][0]) * 100

# %%
#plotting GAP and AE data
plt.figure(figsize=(14,12))

marker_date = '2015-02-01'

plt.plot(df_gap['Date'],df_gap['price_percentage_change_closing'],linestyle='-')
plt.plot(df_ae['Date'],df_ae['price_percentage_change_closing'],linestyle='-')

plt.xlabel('Year', fontsize =18)
plt.ylabel('Sales', fontsize =18)
plt.title('Percent Change in Historical Stock Price from 2014-2019', fontsize = 24)
plt.grid(True)
plt.show()
